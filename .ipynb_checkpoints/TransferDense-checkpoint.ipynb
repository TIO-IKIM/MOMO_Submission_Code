# %%
#author: Anonymous

#Imports

import torch
import torch.nn as nn
import torch.nn.functional as nnf
import torch.optim as optim
from torchvision import datasets, transforms
import torchvision
import torchvision.transforms.functional as ttf
import torch.distributed as dist
import torch.multiprocessing as mp
from torch.nn.parallel import DistributedDataParallel as DDP

import os
import time

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
import random
import itertools
import json as js
import pandas as pd
from scipy import stats

import DatasetFunctions as df

from collections import Counter
from tqdm import tqdm

import pydicom
import SimpleITK as sitk

#device = torch.device("cpu")
device = torch.device("cuda")# if torch.cuda.is_available() else "cpu")

# %%
def representation(SEFN):
    """
    Make a ResNet-usable (224x224x3) representation of an arbitrary input image. There is no center-cropping,
    because we might lose valuable parts of the image (like the Abdomen in a CTTA).
    This function is called by MOMO during evaluation.
    """
    # Resample image to correct size
    sitkreader = sitk.ImageSeriesReader()
    sitkreader.SetFileNames(SEFN)
    sitk_image = sitkreader.Execute()
    representation = df.make_representation_from_unknown(current_image = sitk_image, target_size=(224, 224, 224))
    
    # Add a batch dimension
    representation = torch.unsqueeze(torch.Tensor(representation), 0)
    
    # Squeeze to [0,1]
    representation -= representation.min()
    representation /= representation.max()
    
    # Example normalization to ImageNet-mean/std
    ct = transforms.Compose([transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])
    transformed_representation = ct(representation)
    
    return transformed_representation

# %%
class _ECELoss(nn.Module):
    """
    Calculates the Expected Calibration Error of a model.
    (This isn't necessary for temperature scaling, just a cool metric).
    The input to this loss is the logits of a model, NOT the softmax scores.
    This divides the confidence outputs into equally-sized interval bins.
    In each bin, we compute the confidence gap:
    bin_gap = | avg_confidence_in_bin - accuracy_in_bin |
    We then return a weighted average of the gaps, based on the number
    of samples in each bin
    See: Naeini, Mahdi Pakdaman, Gregory F. Cooper, and Milos Hauskrecht.
    "Obtaining Well Calibrated Probabilities Using Bayesian Binning." AAAI.
    2015.
    PyTorch adaptation by Geoff Pleiss.
    """
    def __init__(self, n_bins=10):
        """
        n_bins (int): number of confidence interval bins
        """
        super(_ECELoss, self).__init__()
        bin_boundaries = torch.linspace(0, 1, n_bins + 1)
        self.bin_lowers = bin_boundaries[:-1]
        self.bin_uppers = bin_boundaries[1:]

    def forward(self, logits, targets):
        softmaxes = nnf.softmax(logits, dim=1)
        confidences, predictions = torch.max(softmaxes, 1)
        accuracies = predictions.eq(targets)

        ece = torch.zeros(1, device=logits.device)
        for bin_lower, bin_upper in zip(self.bin_lowers, self.bin_uppers):
            # Calculated |confidence - accuracy| in each bin
            in_bin = confidences.gt(bin_lower.item()) * confidences.le(bin_upper.item())
            prop_in_bin = in_bin.float().mean()
            if prop_in_bin.item() > 0:
                accuracy_in_bin = accuracies[in_bin].float().mean()
                avg_confidence_in_bin = confidences[in_bin].mean()
                ece += torch.abs(avg_confidence_in_bin - accuracy_in_bin) * prop_in_bin

        return ece
    
def ECE_bin_plot(logits, targets, n_bins, title):
    bin_boundaries = torch.linspace(0, 1, n_bins + 1)
    bin_lowers = bin_boundaries[:-1]
    bin_uppers = bin_boundaries[1:]
    bin_centers = (bin_uppers-bin_lowers)/2 + bin_lowers
    
    softmaxes = nnf.softmax(logits, dim=1)
    confidences, predictions = torch.max(softmaxes, 1)
    accuracies = predictions.eq(targets)
    
    bin_accs = []
    bin_cons = []
    
    for bin_lower, bin_upper in zip(bin_lowers, bin_uppers):
        # Calculated |confidence - accuracy| in each bin
        in_bin = confidences.gt(bin_lower.item()) * confidences.le(bin_upper.item())
        accuracy_in_bin = accuracies[in_bin].float().mean()
        avg_confidence_in_bin = confidences[in_bin].mean()
        bin_accs.append(accuracy_in_bin.item())
        bin_cons.append(avg_confidence_in_bin.item())
    
    plt.figure()
    plt.title(title)
    plt.xlabel('Confidence')
    plt.ylabel('Avg accuracy in bin')
    plt.xlim(0,1)
    plt.ylim(0,1)
    plt.bar(bin_centers, bin_accs, width=1/n_bins, color='b', edgecolor='k', alpha=0.5, label="Accuracy")
    plt.bar(bin_centers, bin_cons, width=1/n_bins, color='r', edgecolor='k', alpha=0.5, label="Confidence")
    plt.plot(np.linspace(0,1,10), np.linspace(0,1,10), 'k--', linewidth=2.0, label='Optimal behaviour')
    plt.legend(loc='upper left')
    plt.show()

class ModelWithTemperature(nn.Module):
    """
    A thin decorator, which wraps a model with temperature scaling
    model (nn.Module):
        A classification neural network
        NB: Output of the neural network should be the classification logits,
            NOT the softmax (or log softmax)!
    """
    def __init__(self, model):
        super(ModelWithTemperature, self).__init__()
        self.model = model
        self.temperature = nn.Parameter(torch.ones(1) * 1.5)

    def forward(self, input):
        logits = self.model(input)
        return self.temperature_scale(logits)

    def temperature_scale(self, logits):
        """
        Perform temperature scaling on logits
        """
        # Expand temperature to match the size of logits
        temperature = self.temperature.unsqueeze(1).expand(logits.size(0), logits.size(1))
        return logits / temperature

    # This function probably should live outside of this class, but whatever
    def set_temperature(self, valid_loader):
        """
        Tune the tempearature of the model (using the validation set).
        We're going to set it to optimize NLL.
        valid_loader (DataLoader): validation set loader
        """
        self.cuda()
        nll_criterion = nn.CrossEntropyLoss().cuda() 
        ece_criterion = _ECELoss().cuda()

        # First: collect all the logits and labels for the validation set
        logits_list = []
        labels_list = []
        with torch.no_grad():
            for data, label, dindex in valid_loader:
                data = data.cuda()
                logits = self.model(data)
                logits_list.append(logits)
                labels_list.append(label)
            logits = torch.cat(logits_list).cuda()
            labels = torch.cat(labels_list).cuda()

        # Calculate NLL and ECE before temperature scaling
        #before_temperature_nll = nll_criterion(logits, labels).item()
        before_temperature_nll = nnf.nll_loss(nnf.log_softmax(logits, dim=1), labels).item()
        before_temperature_ece = ece_criterion(logits, labels).item()
        print('Before temperature - NLL: %.3f, ECE: %.3f' % (before_temperature_nll, before_temperature_ece))
        
        ECE_bin_plot(logits, labels, n_bins=10, title="Uncalibrated network accuracies")

        # Next: optimize the temperature w.r.t. NLL
        optimizer = optim.LBFGS([self.temperature], lr=0.01, max_iter=50)

        def evaluate():
            #loss = nll_criterion(self.temperature_scale(logits), labels)
            loss = ece_criterion(self.temperature_scale(logits), labels)
            loss.backward()
            return loss
        optimizer.step(evaluate)

        # Calculate NLL and ECE after temperature scaling
        #after_temperature_nll = nll_criterion(self.temperature_scale(logits), labels).item()
        after_temperature_nll = nnf.nll_loss(nnf.log_softmax(logits, dim=1), labels).item()
        after_temperature_ece = ece_criterion(self.temperature_scale(logits), labels).item()
        print('Optimal temperature: %.3f' % self.temperature.item())
        print('After temperature - NLL: %.3f, ECE: %.3f' % (after_temperature_nll, after_temperature_ece))
        
        ECE_bin_plot(self.temperature_scale(logits), labels, n_bins=10, title="T-Calibrated network accuracies")

        return self
    
def plot_item(dataloader, idx, classified_as=None, mapping=None):
    data, target, dindex = dataloader.dataset.__getitem__(idx)
    print(target)
    fig = plt.figure(figsize=(16, 6))
    if classified_as:
        if mapping:
            fig.suptitle("Image "+str(idx)+" (class "+str(target)+"/"+str(mapping["Internal"]["Code"][str(target)])+"), classified as "+str(classified_as)+"/"+str(mapping["Internal"]["Code"][str(classified_as)]), fontsize = 30)
        else:
            fig.suptitle("Image "+str(idx)+" (class "+str(target)+"), classified as "+str(classified_as), fontsize = 30)
    else:
        if mapping:
            fig.text(x=0.25, y=0.9, s="Image "+str(idx)+" (class "+str(target)+"/"+str(mapping["Internal"]["Code"][str(target)])+")", fontsize = 30)
        else:
            fig.text(x=0.25, y=0.9, s="Image "+str(idx)+" (class "+str(target)+")", fontsize = 30)
    for z in range(3):
        ax = fig.add_subplot(1,3,z+1)
        ax.set_title("Image "+str(idx)+" (with class "+str(target)+"), z="+str(z))
        ax.imshow(data[z,:,:].cpu().detach().numpy())

# %%
def train_model(model, current_epoch, train_loader, lr, lr_decay, weight_decay, verbose=True):
    
    model.to(device)
    model.train()

    # optimizer, scheduler, no temp
    optimizer = torch.optim.Adam(model.parameters(), lr = lr, weight_decay = weight_decay)
    scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda = lr_decay)
    
    bid = 0
    epoch_losses = 0
    
    for data, target, dindex in train_loader:
        
        # forward
        optimizer.zero_grad()
        output = model(data)
        
        nll_loss = nnf.nll_loss(nnf.log_softmax(output, dim=1), target.to(output.device))
        loss = nll_loss

        # backward
        loss.backward()
        #torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        scheduler.step()
        
        bid += 1
        if verbose==True:
            print('Epoch:'+str(current_epoch)+', Batch ID:'+str(bid)+', Loss:'+str(loss.item()))
        epoch_losses += loss.item()
        
    return epoch_losses / (bid + 1)

def calibrate_model(model, temp_loader):
    
    scaled_model = ModelWithTemperature(model)
    scaled_model.eval()
    scaled_model.set_temperature(temp_loader)
    
    return scaled_model
    
def test_model(model,
               loader,
               nc,
               mapfile = './MCMapping.json',
               plot_cm = True,
               print_mistakes = False,
               plot_mistakes = False):
    
    model.eval()
    model.model.eval()
    
    test_loss = 0
    correct = 0
    print("n_classes: ", nc)
    all_predictions = []
    all_probabilities = []
    all_targets = []
    
    with torch.no_grad():
        cmt = torch.zeros(nc, nc, dtype = torch.int64)
        logits_list = []
        labels_list = []

        # load mapping
        with open(mapfile) as json_file:
            mapping = js.load(json_file)
            classes = list(mapping["Internal"]["Code"].values())[0:nc+1]
        
        for data, target, dindex in loader:
            # send to device
            #data, target = data.to(device), target.to(device)

            # generate output
            output = model(data)
            #print(output)
            
            # remember raw logits for ECE plot
            logits_list.append(output)
            labels_list.append(target)
            
            # compute loss, accuracy, gather mistakes
            lsm = nnf.log_softmax(output, dim=1).to(output.device) #/model.temperature
            softmax = nnf.softmax(output, dim=1).to(output.device) #/model.temperature
            test_loss += nnf.nll_loss(lsm, target.to(output.device), reduction='sum').item() # sum up batch loss
            pred = lsm.data.max(1, keepdim=True)[1] # get the index of the max log-probability
            prob = softmax.data.max(1, keepdim=True)[0]
            for idx, p in enumerate(pred):
                # populate confusion matrix. grab predictions, targets, probabilities
                t = target.to(output.device).data.view_as(pred)[idx].item()
                d = dindex.to(output.device).data.view_as(pred)[idx].item()
                cmt[p.item(),t] += 1
                all_predictions.append(p.item())
                all_targets.append(t)
                b = prob.data.view_as(pred)[idx].item()
                all_probabilities.append(b)
                # if set to print all mistakes, do
                if p != t:
                    if print_mistakes == True:
                        print("Classified "+str(classes[t])+" as "+str(classes[p.item()]))
                        try:
                            print("Had "+str(trhist[0][t])+" "+str(classes[t])+", "+str(trhist[0][p.item()])+" "+str(classes[p.item()])+" training examples.")
                        except:
                            print("Had "+str(trhist[0][t])+" "+str(classes[t])+", 0 "+str(classes[p.item()])+" training examples.")
                    if plot_mistakes == True:
                        plot_item(dataloader = loader, idx = d, classified_as = p.item(), mapping = mapping)
            correct += pred.eq(target.to(output.device).data.view_as(pred)).cuda().sum().item()
        
        # print accuracy
        test_loss /= len(loader.dataset)
        accuracy = 100. * correct / len(loader.dataset)
        print('Loss:'+str(test_loss)+',Accuracy:'+str(accuracy)+'%')
        
        # plot ECE Bin plot
        logits = torch.cat(logits_list).cuda()
        labels = torch.cat(labels_list).cuda()
        ECE_bin_plot(logits, labels, n_bins=10, title="T-Calibrated network accuracies (test set)")

        # plot confusion matrix
        if plot_cm == True:

            cm = cmt.detach().numpy()

            plt.figure(figsize=(40,40)) 
            ax = plt.gca()
            img = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.plasma)
            plt.title("Confusion Matrix")
            tick_marks = np.arange(len(classes))
            plt.xticks(tick_marks, classes, rotation = 90)
            plt.yticks(tick_marks, classes)
            fmt = 'd'
            threshold = cm.max() * 0.33
            for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
                plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="b" if cm[i, j] > threshold else "w")
            plt.tight_layout()
            plt.xlabel('Target')
            plt.ylabel('Prediction')
            divider = make_axes_locatable(ax)
            cax = divider.append_axes("right", size="5%", pad=0.5)
            plt.colorbar(img, cax = cax)
        
        return all_predictions, all_probabilities, all_targets, accuracy

# %%
def get_indices(lower, upper, length):
    return [i for i in range(length) if i>=lower and i<upper]

# Make dataset

nc = 13 # n_classes
ct = transforms.Compose([transforms.Resize([int(224), int(224)]),
                         transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])
                         ])

dataset = df.LAZY_Dataset(data_root='./Removed_for_publication',
                          p_rotflip=0.2,
                          custom_transform=None)

dl = dataset.__len__()
vs = int(0.10*dl) # validation set size
ts = int(0.10*dl) # test set size

# Randomly shuffle the dataset
dataset = torch.utils.data.random_split(dataset, [dl])[0]

# %%
k = 0
temp_inds = get_indices(lower=int(0+k*(vs+ts)), upper=int(vs+k*(vs+ts)), length=dl)
test_inds = get_indices(lower=int(vs+k*(vs+ts)), upper=int((k+1)*(vs+ts)), length=dl)
train_inds = [i for i in range(dl) if not (i in temp_inds or i in test_inds)]

trainset = torch.utils.data.Subset(dataset, train_inds)
tempset = torch.utils.data.Subset(dataset, temp_inds)
testset = torch.utils.data.Subset(dataset, test_inds)

trdist = [targets for _, targets, _ in trainset]
tmdist = [targets for _, targets, _ in tempset]
tedist = [targets for _, targets, _ in testset]

plt.figure()
trhist = plt.hist(trdist, bins=np.arange(0,nc+1), color='r', edgecolor='k') # last bin is nans, it should be empty
plt.title("Class distribution in training set")
plt.xlim(0,nc)

plt.figure()
tmhist = plt.hist(tmdist, bins=np.arange(0,nc+1), color='g', edgecolor='k') # last bin is nans, it should be empty
plt.title("Class distribution in tscaling validation set")
plt.xlim(0,nc)

plt.figure()
tehist = plt.hist(tedist, bins=np.arange(0,nc+1), color='b', edgecolor='k') # last bin is nans, it should be empty
plt.title("Class distribution in test set")
plt.xlim(0,nc)

train_loader = torch.utils.data.DataLoader(trainset, batch_size=24, num_workers=4, shuffle=True, drop_last=False)

tempset.training = False
temp_loader = torch.utils.data.DataLoader(tempset, batch_size=24, num_workers=4, shuffle=True)

testset.training = False
test_loader = torch.utils.data.DataLoader(testset, batch_size=24, shuffle=True)

# %%
# import a densenet, freeze it, swap in final layer
DN_model = torch.nn.DataParallel(torchvision.models.densenet161(pretrained=True)).to(device)
for param in DN_model.parameters():
    param.requires_grad = False
for param in DN_model.module.features.denseblock4.denselayer24.parameters():
    param.requires_grad = True
for param in DN_model.module.features.norm5.parameters():
    param.requires_grad = True
num_ftrs = DN_model.module.classifier.in_features
DN_model.module.classifier = nn.Linear(num_ftrs, nc)

# training hyperparameters
lr = 1e-4 # learning rate
lr_decay = lambda current_epoch: 0.99**current_epoch # learning rate decay function
w_decay = 1e-4 # weight decay

# conditions and schedules
esa = True # early stopping allowed
vis = 5   # how many epochs must plateau before break
imp = 0.99 # suggested loss improvement to continue training
def training_converged(lel, vis, imp):
    return sum(x for x in lel[-2*int(vis):-1*int(vis)])/vis * imp < sum(x for x in lel[-1*int(vis):])/vis

wda = 0.5  # at which fraction of average early loss should weight_decay becomes active

# train
lel = []
for epoch in range(1000):
    # weight decay active?
    if epoch != 0:
        if el <= wda * lel[0]:
            weight_decay = w_decay
        else:
            weight_decay = 0
    else:
        weight_decay = 0
        
    # train model
    el = train_model(model = DN_model,
                current_epoch = epoch,
                train_loader = train_loader,
                lr = lr,
                lr_decay = lr_decay,
                weight_decay = weight_decay)
        
    # track average loss during epoch                                                    
    lel.append(el)
    
    # end training due to convergence?
    if epoch > vis:
        print("Recent average training loss: "+str(sum(x for x in lel[-1*int(vis)-1:-1])/vis))
        print("Current average training loss: "+str(sum(x for x in lel[-1*int(vis):])/vis))
    if epoch >=2*vis:
        if training_converged(lel, vis = vis, imp = imp):
            if esa:
                print("Network parameters appear to have converged, aborting training.")
                # training has not improved loss to factor imp compared to avg of the last vis epochs, end training
                break
            else:
                print("Continuing training. Warning: Convergence satisfies user-specified conditions already.")
        else:
            print("Continuing training.")
            
plt.figure()
plt.title("Loss history during training")
plt.xlim(0,len(lel)-1)
plt.ylim(0,max(lel)*1.2)
plt.xlabel("Epoch")
plt.ylabel("Loss (NLL)")
x = np.linspace(0, len(lel), len(lel))
plt.plot(x, lel, color='k', linewidth=2)
# Out:
# Epoch:0, Batch ID:1, Loss:2.5847153663635254
# Epoch:0, Batch ID:2, Loss:2.6371781826019287
# Epoch:0, Batch ID:3, Loss:2.6445882320404053
# Epoch:0, Batch ID:4, Loss:2.621290683746338
# Epoch:0, Batch ID:5, Loss:2.503830671310425
# Epoch:0, Batch ID:6, Loss:2.4651005268096924
# Epoch:0, Batch ID:7, Loss:2.5787353515625
# Epoch:0, Batch ID:8, Loss:2.626356363296509
# Epoch:0, Batch ID:9, Loss:2.577860116958618
# Epoch:0, Batch ID:10, Loss:2.4801223278045654
# Epoch:0, Batch ID:11, Loss:2.443588972091675
# Epoch:0, Batch ID:12, Loss:2.4543304443359375
# Epoch:0, Batch ID:13, Loss:2.5483815670013428
# Epoch:0, Batch ID:14, Loss:2.551194429397583
# Epoch:0, Batch ID:15, Loss:2.575085401535034
# Epoch:0, Batch ID:16, Loss:2.4631059169769287
# Epoch:0, Batch ID:17, Loss:2.5457284450531006
# Epoch:0, Batch ID:18, Loss:2.494615077972412
# Epoch:0, Batch ID:19, Loss:2.448990821838379
# Epoch:0, Batch ID:20, Loss:2.4781012535095215
# Epoch:0, Batch ID:21, Loss:2.347724199295044
# Epoch:0, Batch ID:22, Loss:2.589348554611206
# Epoch:0, Batch ID:23, Loss:2.539517641067505
# Epoch:0, Batch ID:24, Loss:2.47196888923645
# Epoch:0, Batch ID:25, Loss:2.3453598022460938
# Epoch:0, Batch ID:26, Loss:2.4556691646575928
# Epoch:0, Batch ID:27, Loss:2.374419927597046
# Epoch:0, Batch ID:28, Loss:2.486464023590088
# Epoch:0, Batch ID:29, Loss:2.4658734798431396
# Epoch:0, Batch ID:30, Loss:2.4366462230682373
# Epoch:0, Batch ID:31, Loss:2.5130114555358887
# Epoch:0, Batch ID:32, Loss:2.446723222732544
# Epoch:0, Batch ID:33, Loss:2.4829564094543457
# Epoch:0, Batch ID:34, Loss:2.4009482860565186
# Epoch:0, Batch ID:35, Loss:2.5555837154388428
# Epoch:0, Batch ID:36, Loss:2.424337863922119
# Epoch:0, Batch ID:37, Loss:2.5673627853393555
# Epoch:0, Batch ID:38, Loss:2.4065940380096436
# Epoch:0, Batch ID:39, Loss:2.4634554386138916
# Epoch:0, Batch ID:40, Loss:2.445801019668579
# Epoch:0, Batch ID:41, Loss:2.4080398082733154
# Epoch:0, Batch ID:42, Loss:2.3182342052459717
# Epoch:0, Batch ID:43, Loss:2.458937883377075
# Epoch:0, Batch ID:44, Loss:2.413764476776123
# Epoch:0, Batch ID:45, Loss:2.4679629802703857
# Epoch:0, Batch ID:46, Loss:2.3602817058563232
# Epoch:0, Batch ID:47, Loss:2.3621432781219482
# Epoch:110, Batch ID:52, Loss:0.05016731098294258
# Epoch:110, Batch ID:53, Loss:0.0963268056511879
# Epoch:110, Batch ID:54, Loss:0.01541481539607048
# Epoch:110, Batch ID:55, Loss:0.01627836935222149
# Epoch:110, Batch ID:56, Loss:0.01643974334001541
# Epoch:110, Batch ID:57, Loss:0.03345051035284996
# Epoch:110, Batch ID:58, Loss:0.027146873995661736
# Epoch:110, Batch ID:59, Loss:0.031074099242687225
# Epoch:110, Batch ID:60, Loss:0.01285931933671236
# Epoch:110, Batch ID:61, Loss:0.05318642035126686
# Epoch:110, Batch ID:62, Loss:0.035256754606962204
# Epoch:110, Batch ID:63, Loss:0.05970439314842224
# Epoch:110, Batch ID:64, Loss:0.17360709607601166
# Epoch:110, Batch ID:65, Loss:0.02566874958574772
# Epoch:110, Batch ID:66, Loss:0.046059343963861465
# Epoch:110, Batch ID:67, Loss:0.016961438581347466
# Epoch:110, Batch ID:68, Loss:0.050932154059410095
# Epoch:110, Batch ID:69, Loss:0.023420268669724464
# Epoch:110, Batch ID:70, Loss:0.041761595755815506
# Epoch:110, Batch ID:71, Loss:0.8350139856338501
# Recent average training loss: 0.06061578771461629
# Current average training loss: 0.061040957967957686
# Network parameters appear to have converged, aborting training.

# %%
# calibrate temperature
DN_Tmodel = calibrate_model(model = DN_model, temp_loader = temp_loader)
# Out:
# Before temperature - NLL: 0.692, ECE: 0.060
# Optimal temperature: 1.503
# After temperature - NLL: 0.692, ECE: 0.054

# %%
#test model
test_loader = torch.utils.data.DataLoader(testset, batch_size=1, shuffle=True)
print("Temperature: T=", DN_Tmodel.temperature.item())
predictions, probabilities, targets, accuracy = test_model(model = DN_Tmodel,
                                                         nc = nc,
                                                         mapfile = './MR_only.json',
                                                         loader = test_loader,
                                                         print_mistakes = True,
                                                         plot_mistakes = False)

for i in range(len(predictions)):
    print("Predicted class "+str(predictions[i])+" with p="+str(probabilities[i])+", target was class "+str(targets[i]))
# Out:
# Temperature: T= 1.502569317817688
# n_classes:  13
# Classified MRL as MRB
# Had 125.0 MRL, 146.0 MRB training examples.
# Classified MRA as MRBE
# Had 107.0 MRA, 153.0 MRBE training examples.
# Classified MRTH as MRL
# Had 154.0 MRTH, 125.0 MRL training examples.
# Classified MROE as MRUE
# Had 113.0 MROE, 130.0 MRUE training examples.
# Classified MRWS as MRH
# Had 88.0 MRWS, 123.0 MRH training examples.
# Classified MRUE as MRA
# Had 130.0 MRUE, 107.0 MRA training examples.
# Classified MRTH as MRBE
# Had 154.0 MRTH, 153.0 MRBE training examples.
# Classified MRL as MRB
# Had 125.0 MRL, 146.0 MRB training examples.
# Classified MRUE as MRSH
# Had 130.0 MRUE, 159.0 MRSH training examples.
# Classified MRWS as MRB
# Had 88.0 MRWS, 146.0 MRB training examples.
# Classified MRH as MRB
# Had 123.0 MRH, 146.0 MRB training examples.
# Classified MRH as MRB
# Had 123.0 MRH, 146.0 MRB training examples.
# Classified MRUE as MRBE
# Had 130.0 MRUE, 153.0 MRBE training examples.
# Classified MRA as MRBE
# Had 107.0 MRA, 153.0 MRBE training examples.
# Classified MRL as MRB
# Had 125.0 MRL, 146.0 MRB training examples.
# Classified MRWS as MRH
# Had 88.0 MRWS, 123.0 MRH training examples.
# Classified MRH as MRL
# Had 123.0 MRH, 125.0 MRL training examples.
# Classified MROE as MRTH
# Had 113.0 MROE, 154.0 MRTH training examples.
# Classified MRSH as MRH
# Had 159.0 MRSH, 123.0 MRH training examples.
# Classified MRL as MRA
# Had 125.0 MRL, 107.0 MRA training examples.
# Classified MRL as MRB
# Had 125.0 MRL, 146.0 MRB training examples.
# Classified MRTH as MRB
# Had 154.0 MRTH, 146.0 MRB training examples.
# Classified MRB as MRH
# Had 146.0 MRB, 123.0 MRH training examples.
# Classified MRB as MRL
# Had 146.0 MRB, 125.0 MRL training examples.
# Classified MRA as MRBE
# Had 107.0 MRA, 153.0 MRBE training examples.
# Classified MRSH as MRS
# Had 159.0 MRSH, 152.0 MRS training examples.
# Classified MRTH as MRA
# Had 154.0 MRTH, 107.0 MRA training examples.
# Classified MRH as MRB
# Had 123.0 MRH, 146.0 MRB training examples.
# Classified MRL as MRB
# Had 125.0 MRL, 146.0 MRB training examples.
# Classified MRB as MRL
# Had 146.0 MRB, 125.0 MRL training examples.
# Classified MRBE as MRTH
# Had 153.0 MRBE, 154.0 MRTH training examples.
# Classified MRA as MRBE
# Had 107.0 MRA, 153.0 MRBE training examples.
# Classified MRB as MRL
# Had 146.0 MRB, 125.0 MRL training examples.
# Classified MRS as MRSH
# Had 152.0 MRS, 159.0 MRSH training examples.
# Classified MRBE as MRA
# Had 153.0 MRBE, 107.0 MRA training examples.
# Classified MRB as MROE
# Had 146.0 MRB, 113.0 MROE training examples.
# Classified MRB as MRL
# Had 146.0 MRB, 125.0 MRL training examples.
# Classified MRH as MRB
# Had 123.0 MRH, 146.0 MRB training examples.
# Classified MRH as MRTH
# Had 123.0 MRH, 154.0 MRTH training examples.
# Loss:0.6510014121498292,Accuracy:81.42857142857143%
# Predicted class 2 with p=0.7294233441352844, target was class 2
# Predicted class 9 with p=0.9652639627456665, target was class 9
# Predicted class 1 with p=0.7488833665847778, target was class 4
# Predicted class 6 with p=0.9685529470443726, target was class 6
# Predicted class 8 with p=0.9349185228347778, target was class 8
# Predicted class 3 with p=0.7010703682899475, target was class 3
# Predicted class 1 with p=0.8999198079109192, target was class 1
# Predicted class 2 with p=0.9614007472991943, target was class 0
# Predicted class 4 with p=0.6665694713592529, target was class 4
# Predicted class 0 with p=0.9345607757568359, target was class 0
# Predicted class 4 with p=0.2842375338077545, target was class 9
# Predicted class 5 with p=0.9851968288421631, target was class 5
# Predicted class 2 with p=0.9907304644584656, target was class 2
# Predicted class 10 with p=0.25845786929130554, target was class 6
# Predicted class 8 with p=0.9683200716972351, target was class 8
# Predicted class 9 with p=0.9657872915267944, target was class 9
# Predicted class 2 with p=0.503535270690918, target was class 2
# Predicted class 6 with p=0.992186427116394, target was class 6
# Predicted class 2 with p=0.8102752566337585, target was class 2
# Predicted class 2 with p=0.8650736808776855, target was class 2
# Predicted class 10 with p=0.8277104496955872, target was class 10
# Predicted class 1 with p=0.9732077717781067, target was class 1
# Predicted class 8 with p=0.7687081694602966, target was class 8
# Predicted class 3 with p=0.3916420638561249, target was class 12
# Predicted class 0 with p=0.499819815158844, target was class 10
# Predicted class 4 with p=0.9248090386390686, target was class 4
# Predicted class 4 with p=0.8392130136489868, target was class 4
# Predicted class 5 with p=0.9924424886703491, target was class 5
# Predicted class 2 with p=0.2958618104457855, target was class 9
# Predicted class 1 with p=0.7348494529724121, target was class 4
# Predicted class 6 with p=0.9077863097190857, target was class 6
# Predicted class 8 with p=0.7512187957763672, target was class 10
# Predicted class 2 with p=0.9659043550491333, target was class 2
# Predicted class 1 with p=0.7863914966583252, target was class 12
# Predicted class 8 with p=0.9589741230010986, target was class 8
# Predicted class 3 with p=0.28129076957702637, target was class 3
# Predicted class 2 with p=0.997168242931366, target was class 2
# Predicted class 1 with p=0.4898917078971863, target was class 3
# Predicted class 12 with p=0.9479146599769592, target was class 12
# Predicted class 1 with p=0.8253399133682251, target was class 3
# Predicted class 9 with p=0.7190884351730347, target was class 9
# Predicted class 2 with p=0.21455521881580353, target was class 10
# Predicted class 2 with p=0.8164357542991638, target was class 2
# Predicted class 4 with p=0.8597366809844971, target was class 4
# Predicted class 2 with p=0.8355921506881714, target was class 0
# Predicted class 1 with p=0.9532544016838074, target was class 4
# Predicted class 3 with p=0.34893766045570374, target was class 12
# Predicted class 11 with p=0.7601812481880188, target was class 11
# Predicted class 10 with p=0.8468888998031616, target was class 10
# Predicted class 10 with p=0.39389967918395996, target was class 10
# Predicted class 9 with p=0.6899383664131165, target was class 9
# Predicted class 10 with p=0.9823517203330994, target was class 10
# Predicted class 8 with p=0.7203994393348694, target was class 8
# Predicted class 4 with p=0.8295387625694275, target was class 3
# Predicted class 9 with p=0.8746101260185242, target was class 9
# Predicted class 7 with p=0.9696491360664368, target was class 7
# Predicted class 9 with p=0.6425591707229614, target was class 9
# Predicted class 1 with p=0.515709400177002, target was class 1
# Predicted class 2 with p=0.9424101710319519, target was class 2
# Predicted class 12 with p=0.9348493814468384, target was class 12
# Predicted class 10 with p=0.8870555758476257, target was class 10
# Predicted class 3 with p=0.6706684231758118, target was class 3
# Predicted class 10 with p=0.871152937412262, target was class 10
# Predicted class 2 with p=0.9838653206825256, target was class 2
# Predicted class 6 with p=0.9747121930122375, target was class 6
# Predicted class 7 with p=0.9747466444969177, target was class 7
# Predicted class 9 with p=0.3591679632663727, target was class 6
# Predicted class 3 with p=0.5450111627578735, target was class 3
# Predicted class 1 with p=0.4356749653816223, target was class 1
# Predicted class 4 with p=0.3637666702270508, target was class 4
# Predicted class 4 with p=0.9605414271354675, target was class 4
# Predicted class 3 with p=0.23437225818634033, target was class 8
# Predicted class 0 with p=0.18595542013645172, target was class 4
# Predicted class 7 with p=0.9319539666175842, target was class 7
# Predicted class 1 with p=0.6360270380973816, target was class 1
# Predicted class 11 with p=0.9802114963531494, target was class 11
# Predicted class 9 with p=0.7394070029258728, target was class 9
# Predicted class 11 with p=0.5796372890472412, target was class 11
# Predicted class 8 with p=0.8419329524040222, target was class 8
# Predicted class 5 with p=0.9437612891197205, target was class 5
# Predicted class 7 with p=0.9845921397209167, target was class 7
# Predicted class 4 with p=0.3876931369304657, target was class 4
# Predicted class 2 with p=0.9553875923156738, target was class 2
# Predicted class 0 with p=0.9592642784118652, target was class 0
# Predicted class 1 with p=0.5519406199455261, target was class 4
# Predicted class 4 with p=0.8493401408195496, target was class 4
# Predicted class 7 with p=0.980230987071991, target was class 7
# Predicted class 9 with p=0.8750227093696594, target was class 9
# Predicted class 11 with p=0.8751234412193298, target was class 11
# Predicted class 4 with p=0.8972594738006592, target was class 4
# Predicted class 4 with p=0.9720046520233154, target was class 4
# Predicted class 1 with p=0.5127100944519043, target was class 9
# Predicted class 12 with p=0.9460351467132568, target was class 12
# Predicted class 8 with p=0.5737341046333313, target was class 8
# Predicted class 4 with p=0.5779945850372314, target was class 4
# Predicted class 3 with p=0.6556355953216553, target was class 1
# Predicted class 1 with p=0.9850063920021057, target was class 1
# Predicted class 6 with p=0.9991663694381714, target was class 6
# Predicted class 6 with p=0.47336187958717346, target was class 6
# Predicted class 4 with p=0.34413328766822815, target was class 1
# Predicted class 4 with p=0.4275630712509155, target was class 4
# Predicted class 5 with p=0.992073655128479, target was class 5
# Predicted class 6 with p=0.964436948299408, target was class 6
# Predicted class 2 with p=0.6899495124816895, target was class 0
# Predicted class 8 with p=0.920324444770813, target was class 8
# Predicted class 5 with p=0.991789698600769, target was class 5
# Predicted class 8 with p=0.751360297203064, target was class 8
# Predicted class 1 with p=0.8089818358421326, target was class 1
# Predicted class 7 with p=0.9135686159133911, target was class 7
# Predicted class 8 with p=0.6624807715415955, target was class 8
# Predicted class 7 with p=0.9575344324111938, target was class 7
# Predicted class 3 with p=0.5410378575325012, target was class 3
# Predicted class 10 with p=0.8264539241790771, target was class 10
# Predicted class 9 with p=0.6069364547729492, target was class 9
# Predicted class 0 with p=0.9743189215660095, target was class 0
# Predicted class 11 with p=0.9502302408218384, target was class 11
# Predicted class 0 with p=0.6418051719665527, target was class 0
# Predicted class 6 with p=0.9721697568893433, target was class 6
# Predicted class 3 with p=0.5451197624206543, target was class 3
# Predicted class 6 with p=0.92914879322052, target was class 6
# Predicted class 10 with p=0.9833295345306396, target was class 10
# Predicted class 6 with p=0.9714566469192505, target was class 6
# Predicted class 7 with p=0.4317421317100525, target was class 8
# Predicted class 7 with p=0.7561953663825989, target was class 7
# Predicted class 0 with p=0.1672964096069336, target was class 9
# Predicted class 9 with p=0.8947160243988037, target was class 9
# Predicted class 8 with p=0.6076419949531555, target was class 8
# Predicted class 0 with p=0.59455806016922, target was class 0
# Predicted class 4 with p=0.9033615589141846, target was class 4
# Predicted class 1 with p=0.5898165702819824, target was class 1
# Predicted class 3 with p=0.6487112045288086, target was class 3
# Predicted class 9 with p=0.846883237361908, target was class 9
# Predicted class 0 with p=0.8828862905502319, target was class 0
# Predicted class 9 with p=0.4842275381088257, target was class 9
# Predicted class 9 with p=0.9030442237854004, target was class 9
# Predicted class 3 with p=0.6319068670272827, target was class 3
# Predicted class 5 with p=0.9895957112312317, target was class 5
# Predicted class 0 with p=0.8674177527427673, target was class 0
# Predicted class 4 with p=0.9547334313392639, target was class 4
# Predicted class 2 with p=0.9772388935089111, target was class 2
# Predicted class 1 with p=0.5754573941230774, target was class 3
# Predicted class 1 with p=0.4373321533203125, target was class 4
# Predicted class 0 with p=0.9030500650405884, target was class 0
# Predicted class 7 with p=0.9037669897079468, target was class 7
# Predicted class 6 with p=0.916251540184021, target was class 6
# Predicted class 5 with p=0.9657778143882751, target was class 5
# Predicted class 4 with p=0.6433820724487305, target was class 1
# Predicted class 0 with p=0.8676244616508484, target was class 0
# Predicted class 8 with p=0.9352407455444336, target was class 8
# Predicted class 7 with p=0.5722367763519287, target was class 7
# Predicted class 10 with p=0.8672124743461609, target was class 10
# Predicted class 3 with p=0.9281238317489624, target was class 3
# Predicted class 11 with p=0.4019117057323456, target was class 11
# Predicted class 1 with p=0.6866027116775513, target was class 1
# Predicted class 5 with p=0.9870237112045288, target was class 5
# Predicted class 1 with p=0.2772340178489685, target was class 1
# Predicted class 12 with p=0.4064081013202667, target was class 12
# Predicted class 2 with p=0.965189516544342, target was class 2
# Predicted class 1 with p=0.9370070695877075, target was class 1
# Predicted class 1 with p=0.6558135151863098, target was class 1
# Predicted class 10 with p=0.2923545241355896, target was class 10
# Predicted class 6 with p=0.9424276351928711, target was class 6
# Predicted class 0 with p=0.9607049822807312, target was class 0
# Predicted class 9 with p=0.22208422422409058, target was class 2
# Predicted class 0 with p=0.5556862950325012, target was class 0
# Predicted class 7 with p=0.9428711533546448, target was class 7
# Predicted class 10 with p=0.901858389377594, target was class 10
# Predicted class 2 with p=0.81903475522995, target was class 0
# Predicted class 2 with p=0.8495438098907471, target was class 2
# Predicted class 8 with p=0.799330472946167, target was class 8
# Predicted class 5 with p=0.9344987869262695, target was class 5
# Predicted class 4 with p=0.5969282388687134, target was class 1
# Predicted class 7 with p=0.7209843993186951, target was class 7
# Predicted class 8 with p=0.6807870864868164, target was class 8
# Predicted class 8 with p=0.42834171652793884, target was class 7
# Predicted class 4 with p=0.49506697058677673, target was class 4
# Predicted class 7 with p=0.9817849397659302, target was class 7
# Predicted class 0 with p=0.893424391746521, target was class 0
# Predicted class 6 with p=0.9909501671791077, target was class 6
# Predicted class 6 with p=0.9053463339805603, target was class 6
# Predicted class 3 with p=0.9726635217666626, target was class 3
# Predicted class 7 with p=0.9765477776527405, target was class 7
# Predicted class 0 with p=0.886408269405365, target was class 0
# Predicted class 7 with p=0.6728302240371704, target was class 7
# Predicted class 7 with p=0.8625258207321167, target was class 7
# Predicted class 2 with p=0.9964159727096558, target was class 2
# Predicted class 6 with p=0.9918888211250305, target was class 6
# Predicted class 8 with p=0.7942680716514587, target was class 8
# Predicted class 6 with p=0.6648670434951782, target was class 6
# Predicted class 7 with p=0.981094479560852, target was class 7
# Predicted class 6 with p=0.9917601943016052, target was class 6
# Predicted class 0 with p=0.9321344494819641, target was class 0
# Predicted class 8 with p=0.9756397604942322, target was class 8
# Predicted class 2 with p=0.9929890632629395, target was class 2
# Predicted class 0 with p=0.5171525478363037, target was class 2
# Predicted class 6 with p=0.5797621011734009, target was class 1
# Predicted class 4 with p=0.7418699264526367, target was class 1
# Predicted class 5 with p=0.9868894815444946, target was class 5
# Predicted class 2 with p=0.2657168507575989, target was class 2
# Predicted class 5 with p=0.9733067750930786, target was class 5
# Predicted class 1 with p=0.2730194330215454, target was class 3
# Predicted class 3 with p=0.6676653623580933, target was class 3
# Predicted class 3 with p=0.4482724368572235, target was class 3
# Predicted class 5 with p=0.9943927526473999, target was class 5
# Predicted class 9 with p=0.4005351662635803, target was class 3
# Predicted class 12 with p=0.9584017992019653, target was class 12
# Predicted class 6 with p=0.8822270035743713, target was class 6
# Predicted class 5 with p=0.9551815986633301, target was class 5
# Predicted class 9 with p=0.9584951996803284, target was class 9
# Predicted class 2 with p=0.8063033223152161, target was class 2

# %%
#torch.save(DN_Tmodel, "./DenseNet_MR_test.pth")

# %%
def ffcv(dataset, nc, smap, saveloc, minacc=0.0):
    # does five-fold cross-validation for the network training
    accuracies = []
    
    for k in range(5):
        
        temp_inds = get_indices(lower=int(0+k*(vs+ts)), upper=int(vs+k*(vs+ts)), length=dl)
        test_inds = get_indices(lower=int(vs+k*(vs+ts)), upper=int((k+1)*(vs+ts)), length=dl)
        train_inds = [i for i in range(dl) if not (i in temp_inds or i in test_inds)]

        trainset = torch.utils.data.Subset(dataset, train_inds)
        tempset = torch.utils.data.Subset(dataset, temp_inds)
        testset = torch.utils.data.Subset(dataset, test_inds)

        trdist = [targets for _, targets, _ in trainset]
        tmdist = [targets for _, targets, _ in tempset]
        tedist = [targets for _, targets, _ in testset]

        train_loader = torch.utils.data.DataLoader(trainset, batch_size=24, num_workers=4, shuffle=True, drop_last=True)

        tempset.training = False
        temp_loader = torch.utils.data.DataLoader(tempset, batch_size=24, num_workers=4, shuffle=True)

        testset.training = False
        #test_loader = torch.utils.data.DataLoader(testset, batch_size=24, shuffle=True)
        
        # import a densenet, freeze it, swap in final layer
        DN_model = torch.nn.DataParallel(torchvision.models.densenet161(pretrained=True)).to(device)
        for param in DN_model.parameters():
            param.requires_grad = False
        for param in DN_model.module.features.denseblock4.denselayer24.parameters():
            param.requires_grad = True
        for param in DN_model.module.features.norm5.parameters():
            param.requires_grad = True
        num_ftrs = DN_model.module.classifier.in_features
        DN_model.module.classifier = nn.Linear(num_ftrs, nc)

        # training hyperparameters
        lr = 1e-4 # learning rate
        lr_decay = lambda current_epoch: 0.99**current_epoch # learning rate decay function
        w_decay = 1e-4 # weight decay

        # conditions and schedules
        esa = True # early stopping allowed
        vis = 5   # how many epochs must plateau before break
        imp = 0.99 # suggested loss improvement to continue training
        def training_converged(lel, vis, imp):
            return sum(x for x in lel[-2*int(vis):-1*int(vis)])/vis * imp < sum(x for x in lel[-1*int(vis):])/vis

        wda = 0.5  # at which fraction of average early loss should weight_decay becomes active

        # train
        lel = []
        for epoch in range(1000):
            # weight decay active?
            if epoch != 0:
                if el <= wda * lel[0]:
                    weight_decay = w_decay
                else:
                    weight_decay = 0
            else:
                weight_decay = 0

            # train model
            el = train_model(model = DN_model,
                        current_epoch = epoch,
                        train_loader = train_loader,
                        lr = lr,
                        lr_decay = lr_decay,
                        weight_decay = weight_decay)

            # track average loss during epoch                                                    
            lel.append(el)

            # end training due to convergence?
            if epoch > vis:
                print("Recent average training loss: "+str(sum(x for x in lel[-1*int(vis)-1:-1])/vis))
                print("Current average training loss: "+str(sum(x for x in lel[-1*int(vis):])/vis))
            if epoch >=2*vis:
                if training_converged(lel, vis = vis, imp = imp):
                    if esa:
                        print("Network parameters appear to have converged, aborting training.")
                        # training has not improved loss to factor imp compared to avg of the last vis epochs, end training
                        break
                    else:
                        print("Continuing training. Warning: Convergence satisfies user-specified conditions already.")
                else:
                    print("Continuing training.")

        #calibrate temperature
        DN_Tmodel = calibrate_model(model = DN_model, temp_loader = temp_loader)
        
        #test model
        test_loader = torch.utils.data.DataLoader(testset, batch_size=1, shuffle=True)
        print("Temperature: T=", DN_Tmodel.temperature.item())
        predictions, probabilities, targets, accuracy = test_model(model = DN_Tmodel,
                                                         nc = nc,
                                                         mapfile = smap,
                                                         test_loader = test_loader,
                                                         print_mistakes = False,
                                                         plot_mistakes = False)

        if all(accuracy > old_acc for old_acc in accuracies) and accuracy > minacc:
            print("New best model! Accuracy: ", accuracy)
            torch.save(DN_Tmodel, saveloc)
        accuracies.append(accuracy)
    return accuracies

accs = ffcv(dataset=dataset, 
            nc=76, 
            smap="./MR_only.json", 
            saveloc="DenseNet_MR_only.pth.pth",
            minacc=80.0)
print(accs, np.mean(accs), (np.mean(accs)-1.96*scipy.stats.sem(accs),np.mean(accs)+1.96*scipy.stats.sem(accs)))
# Out:
# Epoch:0, Batch ID:1, Loss:4.2413225173950195
# Epoch:0, Batch ID:2, Loss:4.34074592590332
# Epoch:0, Batch ID:3, Loss:4.333715438842773
# Epoch:0, Batch ID:4, Loss:4.275058269500732
# Epoch:0, Batch ID:5, Loss:4.329033374786377
# Epoch:0, Batch ID:6, Loss:4.282707691192627
# Epoch:0, Batch ID:7, Loss:4.190767288208008
# Epoch:0, Batch ID:8, Loss:4.222731590270996
# Epoch:0, Batch ID:9, Loss:4.333217144012451
# Epoch:0, Batch ID:10, Loss:4.238954067230225
# Epoch:0, Batch ID:11, Loss:4.263301372528076
# Epoch:0, Batch ID:12, Loss:4.205267429351807
# Epoch:0, Batch ID:13, Loss:4.297152042388916
# Epoch:0, Batch ID:14, Loss:4.300050258636475
# Epoch:0, Batch ID:15, Loss:4.183001518249512
# Epoch:0, Batch ID:16, Loss:4.149307727813721
# Epoch:0, Batch ID:17, Loss:4.230576038360596
# Epoch:0, Batch ID:18, Loss:4.145236015319824
# Epoch:0, Batch ID:19, Loss:4.262455940246582
# Epoch:0, Batch ID:20, Loss:3.9676272869110107
# Epoch:0, Batch ID:21, Loss:4.126576900482178
# Epoch:0, Batch ID:22, Loss:4.157078266143799
# Epoch:0, Batch ID:23, Loss:4.278830528259277
# Epoch:0, Batch ID:24, Loss:4.198622226715088
